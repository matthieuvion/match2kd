# %%
import pandas as pd
import numpy as np
import random
import datetime
from datetime import datetime

import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Notes

# %% [raw]
# # General parameter
# # this is the only difference with classification, use reg:squarederror to do linear regression
# # when labels are in [0,1] we can also use reg:logistic
# objective = reg:squarederror

# %% [markdown]
# ## Dataset preparation

# %% [markdown]
# ### Load dataset

# %%
data = pd.read_parquet('dataset_warzone_kd_bigger.parquet.gzip')
display(data.head())
print(data.shape)
# Out:
#    utcStartSeconds  utcEndSeconds              matchID  duration playlistName  \
# 0     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 1     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 2     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 3     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 4     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
#
#    version gameType  playerCount  teamCount rankedTeams  ...  \
# 0      1.0       wz         40.0       12.0        None  ...
# 1      1.0       wz         40.0       12.0        None  ...
# 2      1.0       wz         40.0       12.0        None  ...
# 3      1.0       wz         40.0       12.0        None  ...
# 4      1.0       wz         40.0       12.0        None  ...
#
#    player.awards.seven  player.awards.eight  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
#    playerStats.objectiveBrLootChopperBoxOpen  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    playerStats.objectiveShieldDamage  player.awards.simultaneous_kill  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#    playerStats.objectiveBrPerseusLockerDoorOpenEe  squad  lobbykd  \
# 0                                             NaN  Quads     1.13
# 1                                             NaN  Quads     1.13
# 2                                             NaN  Quads     1.13
# 3                                             NaN  Quads     1.13
# 4                                             NaN  Quads     1.13
#
#    pct_playerskd      map
# 0           82.5  rebirth
# 1           82.5  rebirth
# 2           82.5  rebirth
# 3           82.5  rebirth
# 4           82.5  rebirth
#
# [5 rows x 154 columns]
# (55270, 154)

# %%
categorical_features = [
    'map',
    'squad'
]
data[categorical_features] = data[categorical_features].astype('category')

# rename 'lobbykd' as 'target', since we want to predict the avg k/d ratio of our game
data = data.rename(columns={'lobbykd':'target'})
data = data.reindex(columns = [col for col in data.columns if col != 'target'] + ['target'])
data.head(2)
# Out:
#    utcStartSeconds  utcEndSeconds              matchID  duration playlistName  \
# 0     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 1     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
#
#    version gameType  playerCount  teamCount rankedTeams  ...  \
# 0      1.0       wz         40.0       12.0        None  ...
# 1      1.0       wz         40.0       12.0        None  ...
#
#    player.awards.seven  player.awards.eight  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
#
#    playerStats.objectiveBrLootChopperBoxOpen  \
# 0                                        NaN
# 1                                        NaN
#
#    playerStats.objectiveShieldDamage  player.awards.simultaneous_kill  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
#
#    playerStats.objectiveBrPerseusLockerDoorOpenEe  squad  pct_playerskd  \
# 0                                             NaN  Quads           82.5
# 1                                             NaN  Quads           82.5
#
#        map  target
# 0  rebirth    1.13
# 1  rebirth    1.13
#
# [2 rows x 154 columns]

# %%
# types, missing values
data.info(max_cols=199, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55270 entries, 0 to 64457
# Data columns (total 154 columns):
#  #    Column                                                                 Non-Null Count  Dtype
# ---   ------                                                                 --------------  -----
#  0    utcStartSeconds                                                        55270 non-null  float64
#  1    utcEndSeconds                                                          55270 non-null  float64
#  2    matchID                                                                55270 non-null  object
#  3    duration                                                               55270 non-null  float64
#  4    playlistName                                                           0 non-null      object
#  5    version                                                                55270 non-null  float64
#  6    gameType                                                               55270 non-null  object
#  7    playerCount                                                            55270 non-null  float64
#  8    teamCount                                                              55270 non-null  float64
#  9    rankedTeams                                                            0 non-null      object
#  10   draw                                                                   55270 non-null  bool
#  11   privateMatch                                                           55270 non-null  bool
#  12   playerStats.kills                                                      55270 non-null  float64
#  13   playerStats.medalXp                                                    55270 non-null  float64
#  14   playerStats.matchXp                                                    55270 non-null  float64
#  15   playerStats.scoreXp                                                    55270 non-null  float64
#  16   playerStats.wallBangs                                                  55270 non-null  float64
#  17   playerStats.score                                                      55270 non-null  float64
#  18   playerStats.totalXp                                                    55270 non-null  float64
#  19   playerStats.headshots                                                  55270 non-null  float64
#  20   playerStats.assists                                                    55270 non-null  float64
#  21   playerStats.challengeXp                                                55270 non-null  float64
#  22   playerStats.rank                                                       55270 non-null  float64
#  23   playerStats.scorePerMinute                                             55270 non-null  float64
#  24   playerStats.distanceTraveled                                           55270 non-null  float64
#  25   playerStats.teamSurvivalTime                                           55270 non-null  float64
#  26   playerStats.deaths                                                     55270 non-null  float64
#  27   playerStats.kdRatio                                                    55270 non-null  float64
#  28   playerStats.bonusXp                                                    55270 non-null  float64
#  29   playerStats.gulagDeaths                                                55270 non-null  float64
#  30   playerStats.timePlayed                                                 55270 non-null  float64
#  31   playerStats.executions                                                 55270 non-null  float64
#  32   playerStats.gulagKills                                                 55270 non-null  float64
#  33   playerStats.nearmisses                                                 55270 non-null  float64
#  34   playerStats.percentTimeMoving                                          55270 non-null  float64
#  35   playerStats.miscXp                                                     55270 non-null  float64
#  36   playerStats.longestStreak                                              55270 non-null  float64
#  37   playerStats.teamPlacement                                              55270 non-null  float64
#  38   playerStats.damageDone                                                 55270 non-null  float64
#  39   playerStats.damageTaken                                                55270 non-null  float64
#  40   player.team                                                            55270 non-null  object
#  41   player.rank                                                            55270 non-null  float64
#  42   player.username                                                        55270 non-null  object
#  43   player.uno                                                             55270 non-null  object
#  44   player.clantag                                                         31703 non-null  object
#  45   player.loadouts                                                        55270 non-null  object
#  46   player.brMissionStats.missionsComplete                                 55164 non-null  float64
#  47   player.brMissionStats.totalMissionXpEarned                             55164 non-null  float64
#  48   player.brMissionStats.totalMissionWeaponXpEarned                       55164 non-null  float64
#  49   player.loadout                                                         55270 non-null  object
#  50   player.awards.gun_butt                                                 4329 non-null   float64
#  51   player.awards.mode_x_eliminate                                         41961 non-null  float64
#  52   player.awards.headshot                                                 26078 non-null  float64
#  53   player.awards.double                                                   8931 non-null   float64
#  54   player.awards.one_shot_two_kills                                       941 non-null    float64
#  55   player.awards.ss_kill_toma_strike                                      326 non-null    float64
#  56   player.awards.streak_5                                                 12250 non-null  float64
#  57   player.awards.longshot                                                 13876 non-null  float64
#  58   player.awards.streak_10                                                1928 non-null   float64
#  59   player.awards.save_teammate                                            9310 non-null   float64
#  60   player.awards.ss_kill_precision_airstrike                              441 non-null    float64
#  61   player.awards.explosive_stick                                          1075 non-null   float64
#  62   player.awards.triple                                                   985 non-null    float64
#  63   player.awards.revenge                                                  8336 non-null   float64
#  64   player.awards.posthumous                                               365 non-null    float64
#  65   player.brMissionStats.missionStatsByType.scavenger.weaponXp            1570 non-null   float64
#  66   player.brMissionStats.missionStatsByType.scavenger.xp                  1570 non-null   float64
#  67   player.brMissionStats.missionStatsByType.scavenger.count               1570 non-null   float64
#  68   player.brMissionStats.missionStatsByType.timedrun.weaponXp             1421 non-null   float64
#  69   player.brMissionStats.missionStatsByType.timedrun.xp                   1421 non-null   float64
#  70   player.brMissionStats.missionStatsByType.timedrun.count                1421 non-null   float64
#  71   player.awards.pointblank                                               10974 non-null  float64
#  72   player.awards.throwingknife_kill                                       6303 non-null   float64
#  73   player.awards.firstblood                                               1191 non-null   float64
#  74   player.awards.low_health_kill                                          16217 non-null  float64
#  75   player.awards.kill_jumper                                              3215 non-null   float64
#  76   player.awards.slide_kill                                               794 non-null    float64
#  77   player.awards.four                                                     189 non-null    float64
#  78   player.brMissionStats.missionStatsByType.assassination.weaponXp        4209 non-null   float64
#  79   player.brMissionStats.missionStatsByType.assassination.xp              4209 non-null   float64
#  80   player.brMissionStats.missionStatsByType.assassination.count           4209 non-null   float64
#  81   player.awards.one_shot_kill                                            2430 non-null   float64
#  82   player.awards.mode_x_last_alive                                        284 non-null    float64
#  83   playerStats.objectiveBrCacheOpen                                       526 non-null    float64
#  84   player.awards.avenger                                                  3040 non-null   float64
#  85   player.awards.air_to_air_kill                                          1955 non-null   float64
#  86   player.awards.launcher_direct_hit                                      161 non-null    float64
#  87   player.awards.comeback                                                 1993 non-null   float64
#  88   player.awards.air_kill                                                 703 non-null    float64
#  89   player.brMissionStats.missionStatsByType.supply.weaponXp               246 non-null    float64
#  90   player.brMissionStats.missionStatsByType.supply.xp                     246 non-null    float64
#  91   player.brMissionStats.missionStatsByType.supply.count                  246 non-null    float64
#  92   player.brMissionStats.missionStatsByType.masterassassination.weaponXp  940 non-null    float64
#  93   player.brMissionStats.missionStatsByType.masterassassination.xp        940 non-null    float64
#  94   player.brMissionStats.missionStatsByType.masterassassination.count     940 non-null    float64
#  95   playerStats.objectiveTeamWiped                                         105 non-null    float64
#  96   playerStats.objectiveLastStandKill                                     445 non-null    float64
#  97   playerStats.objectiveBrDownEnemyCircle3                                111 non-null    float64
#  98   playerStats.objectiveBrDownEnemyCircle2                                162 non-null    float64
#  99   playerStats.objectiveBrDownEnemyCircle1                                456 non-null    float64
#  100  playerStats.objectiveBrMissionPickupTablet                             343 non-null    float64
#  101  playerStats.objectiveBrKioskBuy                                        224 non-null    float64
#  102  playerStats.objectivePerkMarkedTarget                                  10 non-null     float64
#  103  player.awards.mantle_kill                                              344 non-null    float64
#  104  player.awards.kill_ss_radar_drone_recon                                19 non-null     float64
#  105  player.awards.stunned_kill                                             330 non-null    float64
#  106  player.awards.quad_feed                                                28 non-null     float64
#  107  playerStats.objectiveReviver                                           111 non-null    float64
#  108  playerStats.objectiveBrRogueCacheOpen                                  138 non-null    float64
#  109  player.awards.streak_15                                                304 non-null    float64
#  110  player.awards.grenade_double                                           33 non-null     float64
#  111  player.awards.streak_20                                                52 non-null     float64
#  112  player.brMissionStats.missionStatsByType.domination.weaponXp           16 non-null     float64
#  113  player.brMissionStats.missionStatsByType.domination.xp                 16 non-null     float64
#  114  player.brMissionStats.missionStatsByType.domination.count              16 non-null     float64
#  115  playerStats.objectiveBrVillainContribution                             216 non-null    float64
#  116  playerStats.objectiveMunitionsBoxTeammateUsed                          73 non-null     float64
#  117  playerStats.objectiveDestroyedEquipment                                17 non-null     float64
#  118  player.brMissionStats.missionStatsByType.black_market.weaponXp         89 non-null     float64
#  119  player.brMissionStats.missionStatsByType.black_market.xp               89 non-null     float64
#  120  player.brMissionStats.missionStatsByType.black_market.count            89 non-null     float64
#  121  player.awards.item_impact                                              16 non-null     float64
#  122  player.awards.five                                                     41 non-null     float64
#  123  playerStats.objectiveBrDownEnemyCircle5                                23 non-null     float64
#  124  playerStats.objectiveBrArmoryTraderUse                                 10 non-null     float64
#  125  playerStats.objectiveTrophyDefense                                     1 non-null      float64
#  126  player.awards.six                                                      12 non-null     float64
#  127  playerStats.objectiveMedalScoreSsKillPrecisionAirstrike                5 non-null      float64
#  128  playerStats.objectiveBrHeroContribution                                193 non-null    float64
#  129  playerStats.objectiveEmpedPlayer                                       14 non-null     float64
#  130  playerStats.objectiveHack                                              1 non-null      float64
#  131  playerStats.objectiveBrCommTowerActivated                              16 non-null     float64
#  132  playerStats.objectiveBrDownEnemyCircle4                                28 non-null     float64
#  133  playerStats.objectiveMedalScoreSsKillTomaStrike                        3 non-null      float64
#  134  playerStats.objectiveBrSupplySweepAssist                               27 non-null     float64
#  135  player.awards.fist_kill                                                26 non-null     float64
#  136  playerStats.objectiveBrPeAuavscanUnspotted                             22 non-null     float64
#  137  playerStats.objectiveBrDownEnemyCircle6                                8 non-null      float64
#  138  player.awards.streak_25                                                14 non-null     float64
#  139  playerStats.objectiveEnemyWiped                                        12 non-null     float64
#  140  playerStats.objectiveDestroyedVehicleMedium                            1 non-null      float64
#  141  playerStats.objectiveBrForgottenLockerDoorOpenEe                       1 non-null      float64
#  142  player.awards.backstab                                                 0 non-null      float64
#  143  playerStats.objectiveMedalScoreKillSsRadarDrone                        1 non-null      float64
#  144  player.awards.seven                                                    4 non-null      float64
#  145  player.awards.eight                                                    2 non-null      float64
#  146  playerStats.objectiveBrLootChopperBoxOpen                              6 non-null      float64
#  147  playerStats.objectiveShieldDamage                                      2 non-null      float64
#  148  player.awards.simultaneous_kill                                        2 non-null      float64
#  149  playerStats.objectiveBrPerseusLockerDoorOpenEe                         1 non-null      float64
#  150  squad                                                                  55270 non-null  category
#  151  pct_playerskd                                                          55270 non-null  float64
#  152  map                                                                    55270 non-null  category
#  153  target                                                                 55270 non-null  float64
# dtypes: bool(2), category(2), float64(140), object(10)
# memory usage: 63.9+ MB

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# #### tmp

# %%
data[['matchID', 'playerCount', 'squad', 'map', 'playerStats.damageDone']].sort_values(by='playerStats.damageDone', ascending=False).head(20)
# Out:
#                     matchID  playerCount  squad       map  \
# 38613   1370069958461487008         52.0  Quads  fortkeep
# 55090    855032827875055390         42.0  Quads   rebirth
# 63532  10628305472550279382         40.0  Quads   rebirth
# 10273   7362251540313581052         52.0  Quads  fortkeep
# 39966   3765989571523210640         44.0  Trios   rebirth
# 9986    1501974320764785975         40.0  Quads   rebirth
# 13144  13547399530503207787         52.0  Quads  fortkeep
# 50310   1766746682563678467         40.0  Quads   rebirth
# 49386   2449047677272433734         39.0  Quads   rebirth
# 46143  14089138655969584359         40.0  Quads   rebirth
# 610     9379401294843804520         52.0  Quads  fortkeep
# 46148  14089138655969584359         40.0  Quads   rebirth
# 48181  13632375024105223441         43.0  Quads   rebirth
# 13456   8784297153243350569         54.0  Quads  fortkeep
# 573      154468577565155836         52.0  Quads  fortkeep
# 48155  13632375024105223441         43.0  Quads   rebirth
# 49954  17982059009096455863         52.0  Quads  fortkeep
# 47054   5904384333418494185         52.0  Quads  fortkeep
# 39722  17796329660594603557         51.0  Quads  fortkeep
# 598     9379401294843804520         52.0  Quads  fortkeep
#
#        playerStats.damageDone
# 38613            4.294967e+09
# 55090            1.271800e+04
# 63532            1.239100e+04
# 10273            1.148700e+04
# 39966            1.113800e+04
# 9986             1.056500e+04
# 13144            1.053500e+04
# 50310            1.052700e+04
# 49386            1.047700e+04
# 46143            1.026200e+04
# 610              1.016900e+04
# 46148            1.015600e+04
# 48181            9.868000e+03
# 13456            9.698000e+03
# 573              9.443000e+03
# 48155            9.440000e+03
# 49954            9.380000e+03
# 47054            9.379000e+03
# 39722            9.361000e+03
# 598              9.236000e+03

# %% [markdown]
# ### Quick overall shape/stats at a glance

# %% [markdown]
# The main specificity of our dataset is that each 'record' (match) is 'multi-dimensional' (several players with n stats/features attached): <br>
# I.e. We want to predict the avg kills/deaths (kd) ratio of each match, but each match does not correspond to a single row (a single set of features), but rather to n rows / players playing in this match.<br>
# One Warzone "Resurgence" match --identified with a matchID, can count up to 50 teams of 1 player (solo mode), or up to 57 players when mode is set to duos, trios, quads. Each player (a row) in a match is attached with a number of features (number of kills, deaths, assists, headshots, xp awards...).<br>

# %%
# 807 matches, but 37808 records (players)
print(data.shape)
print(data.matchID.nunique())
# Out:
# (55270, 154)
# 1170

# %%
data.describe()
# Out:
#        utcStartSeconds  utcEndSeconds       duration  version   playerCount  \
# count     5.527000e+04   5.527000e+04   55270.000000  55270.0  55270.000000
# mean      1.662564e+09   1.662565e+09  822161.697123      1.0     47.415017
# std       4.859948e+05   4.859972e+05   50424.444630      0.0      5.087140
# min       1.661549e+09   1.661550e+09  534000.000000      1.0     30.000000
# 25%       1.662241e+09   1.662242e+09  797000.000000      1.0     42.000000
# 50%       1.662377e+09   1.662378e+09  824000.000000      1.0     50.000000
# 75%       1.662850e+09   1.662851e+09  851000.000000      1.0     52.000000
# max       1.663732e+09   1.663733e+09  970000.000000      1.0     58.000000
#
#           teamCount  playerStats.kills  playerStats.medalXp  \
# count  55270.000000       55270.000000         55270.000000
# mean      17.527447           2.838321           110.598969
# std       10.220768           2.996422           211.820421
# min        9.000000           0.000000             0.000000
# 25%       11.000000           1.000000             0.000000
# 50%       14.000000           2.000000            20.000000
# 75%       18.000000           4.000000            80.000000
# max       50.000000          29.000000          3740.000000
#
#        playerStats.matchXp  playerStats.scoreXp  ...  player.awards.backstab  \
# count         55270.000000         55270.000000  ...                     0.0
# mean           3104.130342          4270.571522  ...                     NaN
# std            1783.029725          3539.880240  ...                     NaN
# min               0.000000             0.000000  ...                     NaN
# 25%            1692.000000          1500.000000  ...                     NaN
# 50%            3153.000000          3575.000000  ...                     NaN
# 75%            4324.000000          6175.000000  ...                     NaN
# max           10622.000000         72530.000000  ...                     NaN
#
#        playerStats.objectiveMedalScoreKillSsRadarDrone  player.awards.seven  \
# count                                              1.0                  4.0
# mean                                               2.0                  0.0
# std                                                NaN                  0.0
# min                                                2.0                  0.0
# 25%                                                2.0                  0.0
# 50%                                                2.0                  0.0
# 75%                                                2.0                  0.0
# max                                                2.0                  0.0
#
#        player.awards.eight  playerStats.objectiveBrLootChopperBoxOpen  \
# count                  2.0                                        6.0
# mean                   0.0                                        1.0
# std                    0.0                                        0.0
# min                    0.0                                        1.0
# 25%                    0.0                                        1.0
# 50%                    0.0                                        1.0
# 75%                    0.0                                        1.0
# max                    0.0                                        1.0
#
#        playerStats.objectiveShieldDamage  player.awards.simultaneous_kill  \
# count                           2.000000                              2.0
# mean                            2.000000                              0.0
# std                             1.414214                              0.0
# min                             1.000000                              0.0
# 25%                             1.500000                              0.0
# 50%                             2.000000                              0.0
# 75%                             2.500000                              0.0
# max                             3.000000                              0.0
#
#        playerStats.objectiveBrPerseusLockerDoorOpenEe  pct_playerskd  \
# count                                             1.0   55270.000000
# mean                                              1.0      79.011476
# std                                               NaN       9.189453
# min                                               1.0      60.000000
# 25%                                               1.0      72.500000
# 50%                                               1.0      79.069767
# 75%                                               1.0      85.454545
# max                                               1.0     100.000000
#
#              target
# count  55270.000000
# mean       1.140005
# std        0.132615
# min        0.800000
# 25%        1.040000
# 50%        1.140000
# 75%        1.230000
# max        1.670000
#
# [8 rows x 140 columns]

# %%
data.groupby(by='matchID')[['playerStats.kills', 'playerStats.deaths', 'playerStats.kdRatio', 'playerStats.damageDone']].agg(['count', 'sum', 'mean', 'median'])
# Out:
#                      playerStats.kills                          \
#                                  count    sum      mean median
# matchID
# 10006862765041148091                45  101.0  2.244444    2.0
# 10022431813918295442                46   86.0  1.869565    1.0
# 10082009794454927010                53  185.0  3.490566    3.0
# 10090996203127539604                50   83.0  1.660000    1.0
# 10134718954536800884                46  114.0  2.478261    2.0
# ...                                ...    ...       ...    ...
# 9952914128324669505                 52  163.0  3.134615    3.0
# 9961080040106933532                 40  111.0  2.775000    2.0
# 9963452121608988341                 52  140.0  2.692308    2.0
# 9971642112346017660                 40  115.0  2.875000    2.0
# 9976478907563874466                 53  176.0  3.320755    3.0
#
#                      playerStats.deaths                          \
#                                   count    sum      mean median
# matchID
# 10006862765041148091                 45  107.0  2.377778    2.0
# 10022431813918295442                 46   87.0  1.891304    2.0
# 10082009794454927010                 53  197.0  3.716981    3.0
# 10090996203127539604                 50   85.0  1.700000    1.0
# 10134718954536800884                 46  117.0  2.543478    2.5
# ...                                 ...    ...       ...    ...
# 9952914128324669505                  52  170.0  3.269231    3.0
# 9961080040106933532                  40  115.0  2.875000    3.0
# 9963452121608988341                  52  139.0  2.673077    2.5
# 9971642112346017660                  40  117.0  2.925000    2.0
# 9976478907563874466                  53  181.0  3.415094    4.0
#
#                      playerStats.kdRatio                                 \
#                                    count        sum      mean    median
# matchID
# 10006862765041148091                  45  57.750000  1.283333  0.800000
# 10022431813918295442                  46  54.316667  1.180797  1.000000
# 10082009794454927010                  53  55.233333  1.042138  0.833333
# 10090996203127539604                  50  51.500000  1.030000  1.000000
# 10134718954536800884                  46  49.083333  1.067029  0.708333
# ...                                  ...        ...       ...       ...
# 9952914128324669505                   52  69.788095  1.342079  1.000000
# 9961080040106933532                   40  40.719048  1.017976  0.708333
# 9963452121608988341                   52  51.283333  0.986218  0.500000
# 9971642112346017660                   40  52.007143  1.300179  0.773810
# 9976478907563874466                   53  75.800000  1.430189  0.600000
#
#                      playerStats.damageDone
#                                       count       sum         mean  median
# matchID
# 10006862765041148091                     45   58445.0  1298.777778  1062.0
# 10022431813918295442                     46   44715.0   972.065217   799.5
# 10082009794454927010                     53  104978.0  1980.716981  1658.0
# 10090996203127539604                     50   49394.0   987.880000   715.0
# 10134718954536800884                     46   62215.0  1352.500000  1065.5
# ...                                     ...       ...          ...     ...
# 9952914128324669505                      52   94405.0  1815.480769  1552.0
# 9961080040106933532                      40   67647.0  1691.175000  1528.5
# 9963452121608988341                      52   80934.0  1556.423077  1341.5
# 9971642112346017660                      40   61750.0  1543.750000  1336.0
# 9976478907563874466                      53  101962.0  1923.811321  1874.0
#
# [1170 rows x 16 columns]

# %%
pd.DataFrame(data.isna().sum().div(len(data)).mul(100).sort_values(ascending=False))[0:50]
# Out:
#                                                              0
# playlistName                                        100.000000
# rankedTeams                                         100.000000
# player.awards.backstab                              100.000000
# playerStats.objectiveHack                            99.998191
# playerStats.objectiveMedalScoreKillSsRadarDrone      99.998191
# playerStats.objectiveDestroyedVehicleMedium          99.998191
# playerStats.objectiveTrophyDefense                   99.998191
# playerStats.objectiveBrPerseusLockerDoorOpenEe       99.998191
# playerStats.objectiveBrForgottenLockerDoorOpenEe     99.998191
# player.awards.simultaneous_kill                      99.996381
# playerStats.objectiveShieldDamage                    99.996381
# player.awards.eight                                  99.996381
# playerStats.objectiveMedalScoreSsKillTomaStrike      99.994572
# player.awards.seven                                  99.992763
# playerStats.objectiveMedalScoreSsKillPrecisionA...   99.990954
# playerStats.objectiveBrLootChopperBoxOpen            99.989144
# playerStats.objectiveBrDownEnemyCircle6              99.985526
# playerStats.objectiveBrArmoryTraderUse               99.981907
# playerStats.objectivePerkMarkedTarget                99.981907
# playerStats.objectiveEnemyWiped                      99.978288
# player.awards.six                                    99.978288
# playerStats.objectiveEmpedPlayer                     99.974670
# player.awards.streak_25                              99.974670
# playerStats.objectiveBrCommTowerActivated            99.971051
# player.brMissionStats.missionStatsByType.domina...   99.971051
# player.awards.item_impact                            99.971051
# player.brMissionStats.missionStatsByType.domina...   99.971051
# player.brMissionStats.missionStatsByType.domina...   99.971051
# playerStats.objectiveDestroyedEquipment              99.969242
# player.awards.kill_ss_radar_drone_recon              99.965623
# playerStats.objectiveBrPeAuavscanUnspotted           99.960195
# playerStats.objectiveBrDownEnemyCircle5              99.958386
# player.awards.fist_kill                              99.952958
# playerStats.objectiveBrSupplySweepAssist             99.951149
# player.awards.quad_feed                              99.949340
# playerStats.objectiveBrDownEnemyCircle4              99.949340
# player.awards.grenade_double                         99.940293
# player.awards.five                                   99.925819
# player.awards.streak_20                              99.905916
# playerStats.objectiveMunitionsBoxTeammateUsed        99.867921
# player.brMissionStats.missionStatsByType.black_...   99.838972
# player.brMissionStats.missionStatsByType.black_...   99.838972
# player.brMissionStats.missionStatsByType.black_...   99.838972
# playerStats.objectiveTeamWiped                       99.810024
# playerStats.objectiveBrDownEnemyCircle3              99.799168
# playerStats.objectiveReviver                         99.799168
# playerStats.objectiveBrRogueCacheOpen                99.750317
# player.awards.launcher_direct_hit                    99.708703
# playerStats.objectiveBrDownEnemyCircle2              99.706893
# player.awards.four                                   99.658042

# %%
pd.DataFrame(data.groupby(by='matchID').agg('mean').isna().sum().sort_values(ascending=False))[70:90]
# Out:
#                                                       0
# player.brMissionStats.missionStatsByType.master...  528
# player.awards.triple                                524
# player.awards.explosive_stick                       477
# player.brMissionStats.missionStatsByType.timedr...  331
# player.brMissionStats.missionStatsByType.timedr...  331
# player.brMissionStats.missionStatsByType.timedr...  331
# player.awards.comeback                              310
# player.awards.air_to_air_kill                       289
# player.brMissionStats.missionStatsByType.scaven...  288
# player.brMissionStats.missionStatsByType.scaven...  288
# player.brMissionStats.missionStatsByType.scaven...  288
# player.awards.streak_10                             255
# player.awards.one_shot_kill                         202
# player.awards.kill_jumper                           160
# player.awards.avenger                                93
# player.awards.gun_butt                               40
# player.brMissionStats.missionStatsByType.assass...   24
# player.brMissionStats.missionStatsByType.assass...   24
# player.brMissionStats.missionStatsByType.assass...   24
# player.awards.throwingknife_kill                     17

# %%
# notes:
# EDA : outlier detection on damageDone with max values way above average

# %% [markdown]
# ## XGB Prediction

# %% [markdown]
# ### Train Test Split

# %%
# As we have multidimensional data for each match (one match = several players/rows, make sure we train test split
# keeping all rows (players) with same match Id in respective train or test dataset
# we're keeping 20 pct of match Ids for test dataset

random.seed(42)
match_uuids = list(set(data.matchID.tolist()))
split_ids = random.sample(match_uuids, int(20*len(match_uuids)/100))

test = data.query('matchID in @split_ids')
train = data.query('matchID not in @split_ids')

display(train.head(2))
print(test.shape)
print(train.shape)
# Out:
#    utcStartSeconds  utcEndSeconds              matchID  duration playlistName  \
# 0     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
# 1     1.662835e+09   1.662836e+09  3409667761123289245  821000.0         None
#
#    version gameType  playerCount  teamCount rankedTeams  ...  \
# 0      1.0       wz         40.0       12.0        None  ...
# 1      1.0       wz         40.0       12.0        None  ...
#
#    player.awards.seven  player.awards.eight  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
#
#    playerStats.objectiveBrLootChopperBoxOpen  \
# 0                                        NaN
# 1                                        NaN
#
#    playerStats.objectiveShieldDamage  player.awards.simultaneous_kill  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
#
#    playerStats.objectiveBrPerseusLockerDoorOpenEe  squad  pct_playerskd  \
# 0                                             NaN  Quads           82.5
# 1                                             NaN  Quads           82.5
#
#        map  target
# 0  rebirth    1.13
# 1  rebirth    1.13
#
# [2 rows x 154 columns]
# (11027, 154)
# (44243, 154)

# %% [markdown]
# ### Features engineering

# %% [markdown]
# #### features selection + encode categorical features

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

def shrink_features(df):
    to_keep = [
        'matchID',
        'target',
        'utcEndSeconds',
        'map',
        'squad',
        'duration',
        'playerCount',
        'teamCount',
        'playerStats.kills',
        'playerStats.deaths',
        'playerStats.assists',
        'playerStats.scorePerMinute',
        'playerStats.headshots',
        'playerStats.rank',
        'playerStats.distanceTraveled',
        'playerStats.teamSurvivalTime',
        'playerStats.kdRatio',
        'playerStats.timePlayed',
        'playerStats.percentTimeMoving',
        'playerStats.longestStreak',
        'playerStats.damageDone',
        'playerStats.damageTaken',
        'playerStats.executions',
        'player.awards.revenge',
        'player.awards.pointblank',
        'player.awards.streak_5',
        'player.awards.streak_10',
        'player.awards.gun_butt',
        'player.awards.kill_jumper',
        'player.awards.longshot',
        'player.awards.avenger',
        'player.awards.save_teammate',
        'player.awards.comeback',
        'player.brMissionStats.missionsComplete',
        'player.brMissionStats.missionStatsByType.assassination.count',
        'player.brMissionStats.missionStatsByType.timedrun.count',
        'player.brMissionStats.missionStatsByType.masterassassination.count',
        'player.brMissionStats.missionStatsByType.scavenger.count',
        'player.awards.low_health_kill'
    ]
    return df[to_keep]


def encode_datetime(df):
    """
    Add day of week, hour, from timestamp
    """

    df['utcEndSeconds'] = df['utcEndSeconds'].apply(lambda x: datetime.fromtimestamp(x))
    df['weekday'] = df['utcEndSeconds'].dt.weekday
    df['hour'] = df['utcEndSeconds'].dt.hour
    df.drop('utcEndSeconds', axis=1, inplace=True)
    
    return df

def squad_to_ordinal(df):
    """
    label (ordinal) encoding for 'squad' (Solos, Duos, Trios...) 
    (could also use one hot, but squad is kind of ordinal)
    """
    squad_order = {'Solos':1, 'Duos':2, 'Trios':3, 'Quads':4}
    df['squad_ordinal'] = df['squad'].map(squad_order)
    df['squad_ordinal'] = df['squad_ordinal'].astype('int64')
    df.drop('squad', axis=1, inplace=True)
    
    return df

def one_hot(df, column):
    """
    One Hot Encode one categorical column using sklearn
    """
    enc = OneHotEncoder(handle_unknown='ignore')
    enc.fit(df[[column]])
    encoded_features = enc.transform(df[[column]]).toarray()
    
    df_features = pd.DataFrame(encoded_features)
    columns = enc.get_feature_names_out([column]).tolist()
    df_features.columns = columns
    
    for _ in [df, df_features]:
        _.reset_index(drop=True, inplace=True)
    augmented_df = pd.concat([df, df_features], axis=1)
    augmented_df.drop(column, axis=1, inplace=True)
    
    return augmented_df

# map_ohe = agg = last
# kills, deaths, assists, agg = mean, std, max (last ?)
# others numerical = mean and/or sum  ?

# %% [markdown]
# #### features aggregation : keep one row (players' stats aggregation) per matchID

# %%
detailed_agg_columns_save = [
    'playerStats.kills',
    'playerStats.deaths',
    'playerStats.assists',
    'playerStats.timePlayed',
    'playerStats.teamSurvivalTime',
    'playerStats.scorePerMinute',
    'playerStats.rank',
]

def aggregate_players(df):
    
    # define the columns groups we will aggregate differently
    
    # those features (+target) wont be aggregated (map type is the same for all players etc...)
    no_agg_columns = [
        'target',
        'duration',
        'playerCount',
        'teamCount',
        'weekday',
        'hour',
        'squad_ordinal',
        'map_fortkeep',
        'map_rebirth',
        
    ]
    # for kills, deaths etc, we will calculate more aggr types (std, max...)
    # we based our selection on back and forth EDA + features importance 
    detailed_agg_columns = [
        'playerStats.kills',
        'playerStats.deaths',
        'playerStats.assists',
        'player.awards.streak_5',
        'player.awards.streak_10',
        'playerStats.damageDone',
        'playerStats.damageTaken',
        'playerStats.rank',
        'playerStats.headshots',
        'playerStats.teamSurvivalTime',
        'playerStats.timePlayed',
        'player.brMissionStats.missionStatsByType.scavenger.count',
        'playerStats.scorePerMinute',
        'playerStats.distanceTraveled',
        'player.awards.avenger'   
    ]
    
    # other columns that are neither non aggregable or detailed
    simple_agg_columns = [col for col in df.columns.tolist() if col not in no_agg_columns]
    simple_agg_columns = [col for col in simple_agg_columns if col not in detailed_agg_columns]
    simple_agg_columns.remove('matchID')
    
    # groupby matchID, but keep features/columns that do not need to be agg-ed
    df_core = df.groupby('matchID')[no_agg_columns].agg('last')
    display(df_core.head(1))
    print(f'df_core shape : {df_core.shape}')

    # groupby matchID, deeper aggregation (mean, std, max)
    # on chosen players stats : kills, deaths, assists...
    df_detailed = df.groupby('matchID')[detailed_agg_columns].agg(['mean', 'std', 'max'])
    df_detailed.columns = ['_'.join(x) for x in df_detailed.columns]
    display(df_detailed.head(1))
    print(f'df_detailed shape : {df_detailed.shape}')
    
    # groupby matchID, simple aggregation (mean) for other players stats
    df_simple = df.groupby('matchID')[simple_agg_columns].agg(['mean'])
    df_simple.columns = ['_'.join(x) for x in df_simple.columns]
    display(df_simple.head())
    print(f'df_simple shape : {df_simple.shape}')
    
    df = pd.concat([df_core, df_detailed, df_simple], axis=1)
    display(df.head(1))
    print(f'finale data shape : {df.shape}')
    
    return df

# %%
# encode categorical + aggregations, match_end (datetime)
#declare y (target) and x
#separate train test

# use k fold instead of train - test ?? because our dataset is small. Or 1/ score accu. 2/ metric per fold

# base model : RandomForestRegressor + intuition & our EDA for feature selection (+ basic aggregations) 
# XGB basic : intuition & our EDA for feature selection (+ basic aggregations) + fixed xgboost parameters
# XGB basic + grid search or random search
# XGB feature engineering + shap hypetune

# %% [markdown]
# #### Some EDA after applying features engineering

# %%
from pandas_profiling import ProfileReport

tmp_data = data.copy(deep=True)
tmp_data = shrink_features(tmp_data)
tmp_data = encode_datetime(tmp_data)
tmp_data = squad_to_ordinal(tmp_data)
tmp_data = one_hot(tmp_data, column='map')
tmp_data = aggregate_players(tmp_data)
tmp_data = tmp_data.reset_index(drop=True)
# Out:
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10006862765041148091    1.18  728000.0         45.0       16.0        6    20
#
#                       squad_ordinal  map_fortkeep  map_rebirth
# matchID
# 10006862765041148091              3           0.0          1.0
# df_core shape : (1170, 9)
#                       playerStats.kills_mean  playerStats.kills_std  \
# matchID
# 10006862765041148091                2.244444               2.487748
#
#                       playerStats.kills_max  playerStats.deaths_mean  \
# matchID
# 10006862765041148091                   13.0                 2.377778
#
#                       playerStats.deaths_std  playerStats.deaths_max  \
# matchID
# 10006862765041148091                1.466116                     6.0
#
#                       playerStats.assists_mean  playerStats.assists_std  \
# matchID
# 10006862765041148091                  0.911111                 1.164283
#
#                       playerStats.assists_max  player.awards.streak_5_mean  \
# matchID
# 10006862765041148091                      4.0                     446584.0
#
#                       ...  \
# matchID               ...
# 10006862765041148091  ...
#
#                       player.brMissionStats.missionStatsByType.scavenger.count_max  \
# matchID
# 10006862765041148091                                                NaN
#
#                       playerStats.scorePerMinute_mean  \
# matchID
# 10006862765041148091                       349.927508
#
#                       playerStats.scorePerMinute_std  \
# matchID
# 10006862765041148091                      284.799598
#
#                       playerStats.scorePerMinute_max  \
# matchID
# 10006862765041148091                     1215.517241
#
#                       playerStats.distanceTraveled_mean  \
# matchID
# 10006862765041148091                      110463.055578
#
#                       playerStats.distanceTraveled_std  \
# matchID
# 10006862765041148091                      31001.475958
#
#                       playerStats.distanceTraveled_max  \
# matchID
# 10006862765041148091                         162307.88
#
#                       player.awards.avenger_mean  player.awards.avenger_std  \
# matchID
# 10006862765041148091                     16740.0                    33480.0
#
#                       player.awards.avenger_max
# matchID
# 10006862765041148091                    66960.0
#
# [1 rows x 45 columns]
# df_detailed shape : (1170, 45)
#                       playerStats.kdRatio_mean  \
# matchID
# 10006862765041148091                  1.283333
# 10022431813918295442                  1.180797
# 10082009794454927010                  1.042138
# 10090996203127539604                  1.030000
# 10134718954536800884                  1.067029
#
#                       playerStats.percentTimeMoving_mean  \
# matchID
# 10006862765041148091                           83.807990
# 10022431813918295442                           86.934635
# 10082009794454927010                           80.054260
# 10090996203127539604                           86.177693
# 10134718954536800884                           81.815328
#
#                       playerStats.longestStreak_mean  \
# matchID
# 10006862765041148091                        2.288889
# 10022431813918295442                        1.847826
# 10082009794454927010                        3.415094
# 10090996203127539604                        1.660000
# 10134718954536800884                        2.456522
#
#                       playerStats.executions_mean  player.awards.revenge_mean  \
# matchID
# 10006862765041148091                          0.0               319248.000000
# 10022431813918295442                          0.0               196560.000000
# 10082009794454927010                          0.0               244743.272727
# 10090996203127539604                          0.0               154680.000000
# 10134718954536800884                          0.0               266832.000000
#
#                       player.awards.pointblank_mean  \
# matchID
# 10006862765041148091                  146098.285714
# 10022431813918295442                  173095.384615
# 10082009794454927010                  255216.000000
# 10090996203127539604                  226244.571429
# 10134718954536800884                  143145.600000
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10006862765041148091                      69000.0
# 10022431813918295442                     145152.0
# 10082009794454927010                     230100.0
# 10090996203127539604                     148800.0
# 10134718954536800884                          NaN
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10006862765041148091                        159296.0
# 10022431813918295442                             0.0
# 10082009794454927010                        185688.0
# 10090996203127539604                        213504.0
# 10134718954536800884                        356860.8
#
#                       player.awards.longshot_mean  \
# matchID
# 10006862765041148091                164214.857143
# 10022431813918295442                242681.142857
# 10082009794454927010                262656.000000
# 10090996203127539604                121704.000000
# 10134718954536800884                208669.090909
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10006862765041148091                     204192.000000
# 10022431813918295442                     213051.428571
# 10082009794454927010                     221578.666667
# 10090996203127539604                     255140.571429
# 10134718954536800884                     217104.000000
#
#                       player.awards.comeback_mean  \
# matchID
# 10006862765041148091                          NaN
# 10022431813918295442                          NaN
# 10082009794454927010                     421814.4
# 10090996203127539604                          NaN
# 10134718954536800884                          NaN
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10006862765041148091                                     0.177778
# 10022431813918295442                                     0.065217
# 10082009794454927010                                     0.150943
# 10090996203127539604                                     0.180000
# 10134718954536800884                                     0.086957
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10006862765041148091                                                1.5
# 10022431813918295442                                                1.0
# 10082009794454927010                                                1.0
# 10090996203127539604                                                1.0
# 10134718954536800884                                                1.5
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10006862765041148091                                                1.0
# 10022431813918295442                                                NaN
# 10082009794454927010                                                NaN
# 10090996203127539604                                                NaN
# 10134718954536800884                                                NaN
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10006862765041148091                                                NaN
# 10022431813918295442                                                NaN
# 10082009794454927010                                                NaN
# 10090996203127539604                                                NaN
# 10134718954536800884                                                NaN
#
#                       player.awards.low_health_kill_mean
# matchID
# 10006862765041148091                       122260.363636
# 10022431813918295442                        77600.000000
# 10082009794454927010                       387921.000000
# 10090996203127539604                       214616.727273
# 10134718954536800884                       282457.600000
# df_simple shape : (1170, 16)
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10006862765041148091    1.18  728000.0         45.0       16.0        6    20
#
#                       squad_ordinal  map_fortkeep  map_rebirth  \
# matchID
# 10006862765041148091              3           0.0          1.0
#
#                       playerStats.kills_mean  ...  \
# matchID                                       ...
# 10006862765041148091                2.244444  ...
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10006862765041148091                      69000.0
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10006862765041148091                        159296.0
#
#                       player.awards.longshot_mean  \
# matchID
# 10006862765041148091                164214.857143
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10006862765041148091                          204192.0
#
#                       player.awards.comeback_mean  \
# matchID
# 10006862765041148091                          NaN
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10006862765041148091                                     0.177778
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10006862765041148091                                                1.5
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10006862765041148091                                                1.0
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10006862765041148091                                                NaN
#
#                       player.awards.low_health_kill_mean
# matchID
# 10006862765041148091                       122260.363636
#
# [1 rows x 70 columns]
# finale data shape : (1170, 70)

# %%
tmp_data = tmp_data.sample(n=500)
profile = ProfileReport(tmp_data, title="EDA on engineered features", minimal=True)
profile.to_file("features_pandas_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# notes : some outliers in damageDone, but we keep them as we will encounter them in real life + we're using xgboost

# %% [markdown]
# ### XGBOOST Training and Hyperparameters tuning

# %% [markdown]
# #### Apply features engineering to train test data

# %%
train = shrink_features(train)
train = encode_datetime(train)
train = squad_to_ordinal(train)
train = one_hot(train, column='map')
train = aggregate_players(train)
train = train.reset_index(drop=True)
# Out:
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10082009794454927010    1.34  833000.0         53.0       15.0        4     0
#
#                       squad_ordinal  map_fortkeep  map_rebirth
# matchID
# 10082009794454927010              4           1.0          0.0
# df_core shape : (936, 9)
#                       playerStats.kills_mean  playerStats.kills_std  \
# matchID
# 10082009794454927010                3.490566               3.667018
#
#                       playerStats.kills_max  playerStats.deaths_mean  \
# matchID
# 10082009794454927010                   18.0                 3.716981
#
#                       playerStats.deaths_std  playerStats.deaths_max  \
# matchID
# 10082009794454927010                2.230707                     9.0
#
#                       playerStats.assists_mean  playerStats.assists_std  \
# matchID
# 10082009794454927010                  1.528302                 1.671063
#
#                       playerStats.assists_max  player.awards.streak_5_mean  \
# matchID
# 10082009794454927010                      7.0                436720.941176
#
#                       ...  \
# matchID               ...
# 10082009794454927010  ...
#
#                       player.brMissionStats.missionStatsByType.scavenger.count_max  \
# matchID
# 10082009794454927010                                                1.0
#
#                       playerStats.scorePerMinute_mean  \
# matchID
# 10082009794454927010                       476.720511
#
#                       playerStats.scorePerMinute_std  \
# matchID
# 10082009794454927010                      337.135903
#
#                       playerStats.scorePerMinute_max  \
# matchID
# 10082009794454927010                     1648.351648
#
#                       playerStats.distanceTraveled_mean  \
# matchID
# 10082009794454927010                      140855.366717
#
#                       playerStats.distanceTraveled_std  \
# matchID
# 10082009794454927010                      37584.231903
#
#                       playerStats.distanceTraveled_max  \
# matchID
# 10082009794454927010                          212318.5
#
#                       player.awards.avenger_mean  player.awards.avenger_std  \
# matchID
# 10082009794454927010                     72204.0                   144408.0
#
#                       player.awards.avenger_max
# matchID
# 10082009794454927010                   288816.0
#
# [1 rows x 45 columns]
# df_detailed shape : (936, 45)
#                       playerStats.kdRatio_mean  \
# matchID
# 10082009794454927010                  1.042138
# 10134718954536800884                  1.067029
# 10141051138442727030                  1.158373
# 10150800201941496413                  1.429418
# 10155179111233906919                  1.085833
#
#                       playerStats.percentTimeMoving_mean  \
# matchID
# 10082009794454927010                           80.054260
# 10134718954536800884                           81.815328
# 10141051138442727030                           81.797826
# 10150800201941496413                           81.008081
# 10155179111233906919                           85.657347
#
#                       playerStats.longestStreak_mean  \
# matchID
# 10082009794454927010                        3.415094
# 10134718954536800884                        2.456522
# 10141051138442727030                        3.675000
# 10150800201941496413                        3.384615
# 10155179111233906919                        2.680000
#
#                       playerStats.executions_mean  player.awards.revenge_mean  \
# matchID
# 10082009794454927010                     0.000000               244743.272727
# 10134718954536800884                     0.000000               266832.000000
# 10141051138442727030                     0.000000               384041.142857
# 10150800201941496413                     0.019231               303202.909091
# 10155179111233906919                     0.040000               362840.727273
#
#                       player.awards.pointblank_mean  \
# matchID
# 10082009794454927010                  255216.000000
# 10134718954536800884                  143145.600000
# 10141051138442727030                  277548.000000
# 10150800201941496413                  264676.000000
# 10155179111233906919                  226770.461538
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10082009794454927010                     230100.0
# 10134718954536800884                          NaN
# 10141051138442727030                     176275.2
# 10150800201941496413                     244016.0
# 10155179111233906919                      51408.0
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10082009794454927010                        185688.0
# 10134718954536800884                        356860.8
# 10141051138442727030                        350208.0
# 10150800201941496413                        134112.0
# 10155179111233906919                        281592.0
#
#                       player.awards.longshot_mean  \
# matchID
# 10082009794454927010                262656.000000
# 10134718954536800884                208669.090909
# 10141051138442727030                276020.571429
# 10150800201941496413                248490.000000
# 10155179111233906919                247639.384615
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10082009794454927010                     221578.666667
# 10134718954536800884                     217104.000000
# 10141051138442727030                     301889.454545
# 10150800201941496413                     213700.800000
# 10155179111233906919                     215008.000000
#
#                       player.awards.comeback_mean  \
# matchID
# 10082009794454927010                     421814.4
# 10134718954536800884                          NaN
# 10141051138442727030                     367500.0
# 10150800201941496413                     498348.0
# 10155179111233906919                     596688.0
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10082009794454927010                                     0.150943
# 10134718954536800884                                     0.086957
# 10141051138442727030                                     0.250000
# 10150800201941496413                                     0.173077
# 10155179111233906919                                     0.180000
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10082009794454927010                                                1.0
# 10134718954536800884                                                1.5
# 10141051138442727030                                                1.0
# 10150800201941496413                                                1.0
# 10155179111233906919                                                1.0
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10082009794454927010                                                NaN
# 10134718954536800884                                                NaN
# 10141051138442727030                                                1.0
# 10150800201941496413                                                1.0
# 10155179111233906919                                                1.0
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10082009794454927010                                                NaN
# 10134718954536800884                                                NaN
# 10141051138442727030                                                1.0
# 10150800201941496413                                                NaN
# 10155179111233906919                                                1.0
#
#                       player.awards.low_health_kill_mean
# matchID
# 10082009794454927010                       387921.000000
# 10134718954536800884                       282457.600000
# 10141051138442727030                       329188.000000
# 10150800201941496413                       253433.600000
# 10155179111233906919                       271955.368421
# df_simple shape : (936, 16)
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10082009794454927010    1.34  833000.0         53.0       15.0        4     0
#
#                       squad_ordinal  map_fortkeep  map_rebirth  \
# matchID
# 10082009794454927010              4           1.0          0.0
#
#                       playerStats.kills_mean  ...  \
# matchID                                       ...
# 10082009794454927010                3.490566  ...
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10082009794454927010                     230100.0
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10082009794454927010                        185688.0
#
#                       player.awards.longshot_mean  \
# matchID
# 10082009794454927010                     262656.0
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10082009794454927010                     221578.666667
#
#                       player.awards.comeback_mean  \
# matchID
# 10082009794454927010                     421814.4
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10082009794454927010                                     0.150943
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10082009794454927010                                                1.0
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10082009794454927010                                                NaN
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10082009794454927010                                                NaN
#
#                       player.awards.low_health_kill_mean
# matchID
# 10082009794454927010                            387921.0
#
# [1 rows x 70 columns]
# finale data shape : (936, 70)

# %%
test = shrink_features(test)
test = encode_datetime(test)
test = squad_to_ordinal(test)
test = one_hot(test, column='map')
test = aggregate_players(test)
test = test.reset_index(drop=True)
# Out:
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10006862765041148091    1.18  728000.0         45.0       16.0        6    20
#
#                       squad_ordinal  map_fortkeep  map_rebirth
# matchID
# 10006862765041148091              3           0.0          1.0
# df_core shape : (234, 9)
#                       playerStats.kills_mean  playerStats.kills_std  \
# matchID
# 10006862765041148091                2.244444               2.487748
#
#                       playerStats.kills_max  playerStats.deaths_mean  \
# matchID
# 10006862765041148091                   13.0                 2.377778
#
#                       playerStats.deaths_std  playerStats.deaths_max  \
# matchID
# 10006862765041148091                1.466116                     6.0
#
#                       playerStats.assists_mean  playerStats.assists_std  \
# matchID
# 10006862765041148091                  0.911111                 1.164283
#
#                       playerStats.assists_max  player.awards.streak_5_mean  \
# matchID
# 10006862765041148091                      4.0                     446584.0
#
#                       ...  \
# matchID               ...
# 10006862765041148091  ...
#
#                       player.brMissionStats.missionStatsByType.scavenger.count_max  \
# matchID
# 10006862765041148091                                                NaN
#
#                       playerStats.scorePerMinute_mean  \
# matchID
# 10006862765041148091                       349.927508
#
#                       playerStats.scorePerMinute_std  \
# matchID
# 10006862765041148091                      284.799598
#
#                       playerStats.scorePerMinute_max  \
# matchID
# 10006862765041148091                     1215.517241
#
#                       playerStats.distanceTraveled_mean  \
# matchID
# 10006862765041148091                      110463.055578
#
#                       playerStats.distanceTraveled_std  \
# matchID
# 10006862765041148091                      31001.475958
#
#                       playerStats.distanceTraveled_max  \
# matchID
# 10006862765041148091                         162307.88
#
#                       player.awards.avenger_mean  player.awards.avenger_std  \
# matchID
# 10006862765041148091                     16740.0                    33480.0
#
#                       player.awards.avenger_max
# matchID
# 10006862765041148091                    66960.0
#
# [1 rows x 45 columns]
# df_detailed shape : (234, 45)
#                       playerStats.kdRatio_mean  \
# matchID
# 10006862765041148091                  1.283333
# 10022431813918295442                  1.180797
# 10090996203127539604                  1.030000
# 10153328630378107053                  1.115278
# 10154164266128423971                  1.117628
#
#                       playerStats.percentTimeMoving_mean  \
# matchID
# 10006862765041148091                           83.807990
# 10022431813918295442                           86.934635
# 10090996203127539604                           86.177693
# 10153328630378107053                           84.269078
# 10154164266128423971                           81.230395
#
#                       playerStats.longestStreak_mean  \
# matchID
# 10006862765041148091                        2.288889
# 10022431813918295442                        1.847826
# 10090996203127539604                        1.660000
# 10153328630378107053                        1.395833
# 10154164266128423971                        1.750000
#
#                       playerStats.executions_mean  player.awards.revenge_mean  \
# matchID
# 10006862765041148091                     0.000000                    319248.0
# 10022431813918295442                     0.000000                    196560.0
# 10090996203127539604                     0.000000                    154680.0
# 10153328630378107053                     0.020833                    460080.0
# 10154164266128423971                     0.000000                    334056.0
#
#                       player.awards.pointblank_mean  \
# matchID
# 10006862765041148091                  146098.285714
# 10022431813918295442                  173095.384615
# 10090996203127539604                  226244.571429
# 10153328630378107053                   91392.000000
# 10154164266128423971                  264394.285714
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10006862765041148091                      69000.0
# 10022431813918295442                     145152.0
# 10090996203127539604                     148800.0
# 10153328630378107053                     100240.0
# 10154164266128423971                      68816.0
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10006862765041148091                        159296.0
# 10022431813918295442                             0.0
# 10090996203127539604                        213504.0
# 10153328630378107053                             NaN
# 10154164266128423971                             0.0
#
#                       player.awards.longshot_mean  \
# matchID
# 10006862765041148091                164214.857143
# 10022431813918295442                242681.142857
# 10090996203127539604                121704.000000
# 10153328630378107053                217929.600000
# 10154164266128423971                202704.000000
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10006862765041148091                     204192.000000
# 10022431813918295442                     213051.428571
# 10090996203127539604                     255140.571429
# 10153328630378107053                     103776.000000
# 10154164266128423971                     425196.000000
#
#                       player.awards.comeback_mean  \
# matchID
# 10006862765041148091                          NaN
# 10022431813918295442                          NaN
# 10090996203127539604                          NaN
# 10153328630378107053                     479280.0
# 10154164266128423971                          NaN
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10006862765041148091                                     0.177778
# 10022431813918295442                                     0.065217
# 10090996203127539604                                     0.180000
# 10153328630378107053                                     0.145833
# 10154164266128423971                                          NaN
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10006862765041148091                                                1.5
# 10022431813918295442                                                1.0
# 10090996203127539604                                                1.0
# 10153328630378107053                                                1.0
# 10154164266128423971                                                NaN
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10006862765041148091                                                1.0
# 10022431813918295442                                                NaN
# 10090996203127539604                                                NaN
# 10153328630378107053                                                1.0
# 10154164266128423971                                                NaN
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10006862765041148091                                                NaN
# 10022431813918295442                                                NaN
# 10090996203127539604                                                NaN
# 10153328630378107053                                                1.0
# 10154164266128423971                                                NaN
#
#                       player.awards.low_health_kill_mean
# matchID
# 10006862765041148091                       122260.363636
# 10022431813918295442                        77600.000000
# 10090996203127539604                       214616.727273
# 10153328630378107053                       266934.857143
# 10154164266128423971                       194117.333333
# df_simple shape : (234, 16)
#                       target  duration  playerCount  teamCount  weekday  hour  \
# matchID
# 10006862765041148091    1.18  728000.0         45.0       16.0        6    20
#
#                       squad_ordinal  map_fortkeep  map_rebirth  \
# matchID
# 10006862765041148091              3           0.0          1.0
#
#                       playerStats.kills_mean  ...  \
# matchID                                       ...
# 10006862765041148091                2.244444  ...
#
#                       player.awards.gun_butt_mean  \
# matchID
# 10006862765041148091                      69000.0
#
#                       player.awards.kill_jumper_mean  \
# matchID
# 10006862765041148091                        159296.0
#
#                       player.awards.longshot_mean  \
# matchID
# 10006862765041148091                164214.857143
#
#                       player.awards.save_teammate_mean  \
# matchID
# 10006862765041148091                          204192.0
#
#                       player.awards.comeback_mean  \
# matchID
# 10006862765041148091                          NaN
#
#                       player.brMissionStats.missionsComplete_mean  \
# matchID
# 10006862765041148091                                     0.177778
#
#                       player.brMissionStats.missionStatsByType.assassination.count_mean  \
# matchID
# 10006862765041148091                                                1.5
#
#                       player.brMissionStats.missionStatsByType.timedrun.count_mean  \
# matchID
# 10006862765041148091                                                1.0
#
#                       player.brMissionStats.missionStatsByType.masterassassination.count_mean  \
# matchID
# 10006862765041148091                                                NaN
#
#                       player.awards.low_health_kill_mean
# matchID
# 10006862765041148091                       122260.363636
#
# [1 rows x 70 columns]
# finale data shape : (234, 70)

# %% [markdown]
# #### Fit Xgboost, with cv / early stopping

# %%
X_train = train.drop('target', axis=1).copy()
y_train = train['target'].copy()
X_test = test.drop('target', axis=1).copy()
y_test = test['target'].copy()

# %%
# Sklearn API, default run with a chosen eta of 0.05
# early stopping set to 50 to prevent overfitting
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50, learning_rate=0.05)
reg.fit(
    X_train,
    y_train,
    verbose=10,
    eval_set=[(X_train, y_train), (X_test, y_test)]
)
# Out:
# [0]	validation_0-rmse:0.62055	validation_1-rmse:0.62276
# [10]	validation_0-rmse:0.38338	validation_1-rmse:0.39213
# [20]	validation_0-rmse:0.24292	validation_1-rmse:0.25958
# [30]	validation_0-rmse:0.16004	validation_1-rmse:0.18881
# [40]	validation_0-rmse:0.11238	validation_1-rmse:0.15279
# [50]	validation_0-rmse:0.08558	validation_1-rmse:0.13670
# [60]	validation_0-rmse:0.07024	validation_1-rmse:0.12952
# [70]	validation_0-rmse:0.06137	validation_1-rmse:0.12663
# [80]	validation_0-rmse:0.05534	validation_1-rmse:0.12550
# [90]	validation_0-rmse:0.05048	validation_1-rmse:0.12493
# [100]	validation_0-rmse:0.04557	validation_1-rmse:0.12473
# [110]	validation_0-rmse:0.04138	validation_1-rmse:0.12458
# [120]	validation_0-rmse:0.03763	validation_1-rmse:0.12417
# [130]	validation_0-rmse:0.03388	validation_1-rmse:0.12423
# [140]	validation_0-rmse:0.03060	validation_1-rmse:0.12397
# [150]	validation_0-rmse:0.02826	validation_1-rmse:0.12389
# [160]	validation_0-rmse:0.02605	validation_1-rmse:0.12373
# [170]	validation_0-rmse:0.02394	validation_1-rmse:0.12371
# [180]	validation_0-rmse:0.02247	validation_1-rmse:0.12360
# [190]	validation_0-rmse:0.02096	validation_1-rmse:0.12368
# [200]	validation_0-rmse:0.01932	validation_1-rmse:0.12363
# [210]	validation_0-rmse:0.01794	validation_1-rmse:0.12366
# [220]	validation_0-rmse:0.01687	validation_1-rmse:0.12362
# [230]	validation_0-rmse:0.01549	validation_1-rmse:0.12363
# [240]	validation_0-rmse:0.01430	validation_1-rmse:0.12368
# [250]	validation_0-rmse:0.01333	validation_1-rmse:0.12380
# [260]	validation_0-rmse:0.01241	validation_1-rmse:0.12388
# [270]	validation_0-rmse:0.01166	validation_1-rmse:0.12392
# [276]	validation_0-rmse:0.01118	validation_1-rmse:0.12392
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_).sort_values(by=0, ascending=False).head(50)
# Out:
#                                                            0
# playerStats.damageDone_std                          0.050676
# player.awards.streak_5_mean                         0.047482
# playerStats.timePlayed_mean                         0.044714
# playerStats.rank_mean                               0.035840
# playerStats.damageDone_mean                         0.032639
# playerStats.kills_std                               0.027382
# playerStats.teamSurvivalTime_mean                   0.024951
# playerStats.longestStreak_mean                      0.023215
# playerStats.deaths_max                              0.021821
# playerStats.scorePerMinute_mean                     0.021162
# playerStats.headshots_mean                          0.019935
# playerStats.damageTaken_std                         0.019894
# player.awards.avenger_mean                          0.019654
# playerStats.deaths_mean                             0.018932
# playerStats.deaths_std                              0.018827
# player.brMissionStats.missionStatsByType.assass...  0.018759
# player.awards.avenger_max                           0.018543
# playerStats.damageTaken_mean                        0.018507
# playerStats.distanceTraveled_std                    0.017929
# playerStats.scorePerMinute_max                      0.017134
# playerStats.damageTaken_max                         0.016341
# playerStats.percentTimeMoving_mean                  0.016063
# playerStats.timePlayed_std                          0.015874
# player.awards.streak_10_std                         0.015346
# player.awards.avenger_std                           0.015164
# playerStats.scorePerMinute_std                      0.015066
# playerStats.kdRatio_mean                            0.015037
# player.awards.kill_jumper_mean                      0.015018
# player.awards.save_teammate_mean                    0.015013
# playerStats.headshots_max                           0.014805
# playerStats.headshots_std                           0.014736
# playerStats.teamSurvivalTime_max                    0.014453
# player.brMissionStats.missionStatsByType.timedr...  0.013707
# playerStats.damageDone_max                          0.013634
# player.awards.gun_butt_mean                         0.013382
# playerStats.distanceTraveled_mean                   0.013230
# playerStats.timePlayed_max                          0.013229
# player.awards.comeback_mean                         0.012769
# player.awards.low_health_kill_mean                  0.012447
# playerStats.distanceTraveled_max                    0.012179
# player.awards.pointblank_mean                       0.012160
# player.brMissionStats.missionStatsByType.master...  0.012109
# playerStats.rank_std                                0.011948
# player.awards.streak_10_max                         0.011854
# playerStats.teamSurvivalTime_std                    0.011844
# player.awards.streak_5_max                          0.011223
# player.brMissionStats.missionsComplete_mean         0.010627
# player.awards.longshot_mean                         0.010131
# player.awards.revenge_mean                          0.009710
# playerStats.assists_mean                            0.009604

# %%
# using Xgboost API and cross validation
X = pd.concat([X_train, X_test], axis=0)
print(X.shape)
y = pd.concat([y_train, y_test], axis=0)
print(y.shape)

dmatrix = xgb.DMatrix(data=X, label=y)

params = {
    'objective':'reg:squarederror'
}

cv_results = xgb.cv(
    dtrain=dmatrix, 
    params=params, 
    nfold=10,
    as_pandas=True,
    seed=20,
    num_boost_round=1000
)
print('RMSE: %.4f' % cv_results['test-rmse-mean'].min())
# Out:
# (1170, 69)
# (1170,)
# RMSE: 0.1230

# %%
# using XgBoost API & cv, with a few tuned hyperparameters
dmatrix = xgb.DMatrix(data=X, label=y)

params = {
    'objective':'reg:squarederror',
    'max_depth': 5,
    'colsample_bytree':0.5,
    'learning_rate':0.03,
    'random_state':20
}

cv_results = xgb.cv(
    dtrain=dmatrix, 
    params=params, 
    nfold=10,
    as_pandas=True,
    seed=20,
    metrics={'rmse'},
    num_boost_round=1000
)
print('RMSE: %.4f' % cv_results['test-rmse-mean'].min())
# Out:
# RMSE: 0.1164

# %%
# Random grid search using RandomSearchCV() from Sklearn

from sklearn.model_selection import RandomizedSearchCV

# we already went into back and forth runs to run with below ranges :
params = {
    'learning_rate': [0.03, 0.04, 0.05, 0.06, 0.07],
    'max_depth': [3, 5, 6, 7],
    'subsample': np.arange(0.4, 1.0, 0.1),
    'colsample_bytree': np.arange(0.4, 1.0, 0.1),
    'colsample_bylevel': np.arange(0.4, 1.0, 0.1),
    'n_estimators': [300, 400, 500, 600, 700],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [0, 0.5, 5]
}

xgbr = xgb.XGBRegressor(seed = 20)
clf = RandomizedSearchCV(estimator=xgbr,
                         n_jobs= -1,
                         refit=True, #default would be True anyways
                         param_distributions=params,
                         scoring='neg_mean_squared_error',
                         n_iter=50,
                         verbose=1)
clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'subsample': 0.7, 'reg_lambda': 5, 'reg_alpha': 0, 'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.05, 'colsample_bytree': 0.7999999999999999, 'colsample_bylevel': 0.6}
# Lowest RMSE:  0.11694815374784426

# %%
best_pars = clf.best_params_
print(best_pars)
best_model = clf.best_estimator_
# Out:
# {'subsample': 0.7, 'reg_lambda': 5, 'reg_alpha': 0, 'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.05, 'colsample_bytree': 0.7999999999999999, 'colsample_bylevel': 0.6}

# %%
pd.DataFrame(data=best_model.feature_importances_,
             index=best_model.feature_names_in_).sort_values(by=0, ascending=False).head(50)
# Out:
#                                                            0
# player.awards.streak_5_mean                         0.030659
# playerStats.kills_std                               0.030161
# playerStats.damageDone_std                          0.029609
# playerStats.timePlayed_mean                         0.024837
# playerStats.teamSurvivalTime_mean                   0.022074
# playerStats.damageDone_mean                         0.021969
# playerStats.headshots_mean                          0.021336
# playerStats.rank_std                                0.020857
# playerStats.timePlayed_max                          0.020784
# playerStats.rank_mean                               0.019955
# playerStats.scorePerMinute_std                      0.019004
# playerStats.scorePerMinute_mean                     0.018990
# playerStats.damageTaken_std                         0.018179
# playerStats.longestStreak_mean                      0.017899
# playerStats.teamSurvivalTime_max                    0.016997
# player.awards.avenger_mean                          0.016833
# playerStats.kills_mean                              0.016443
# playerStats.deaths_max                              0.015946
# playerStats.teamSurvivalTime_std                    0.015942
# playerStats.damageTaken_max                         0.015885
# playerStats.damageTaken_mean                        0.015646
# playerStats.scorePerMinute_max                      0.015516
# squad_ordinal                                       0.015310
# playerStats.headshots_std                           0.015191
# player.awards.avenger_max                           0.015130
# player.awards.kill_jumper_mean                      0.015031
# playerStats.deaths_mean                             0.014800
# playerStats.damageDone_max                          0.014013
# player.brMissionStats.missionStatsByType.scaven...  0.013904
# playerStats.distanceTraveled_std                    0.013722
# player.brMissionStats.missionStatsByType.scaven...  0.013475
# player.brMissionStats.missionsComplete_mean         0.013335
# playerStats.distanceTraveled_max                    0.013135
# playerStats.kdRatio_mean                            0.012999
# player.awards.streak_10_max                         0.012981
# playerStats.distanceTraveled_mean                   0.012973
# playerStats.deaths_std                              0.012966
# player.awards.avenger_std                           0.012758
# map_rebirth                                         0.012744
# playerStats.executions_mean                         0.012444
# player.brMissionStats.missionStatsByType.assass...  0.012423
# player.awards.streak_10_mean                        0.012417
# player.awards.save_teammate_mean                    0.012404
# player.awards.comeback_mean                         0.012370
# player.brMissionStats.missionStatsByType.master...  0.012356
# playerStats.timePlayed_std                          0.012219
# player.awards.pointblank_mean                       0.012093
# player.awards.streak_5_max                          0.011957
# player.awards.gun_butt_mean                         0.011826
# player.awards.longshot_mean                         0.011799

# %%
# save best model
best_model.save_model('xgb_model_lobby_kd.json')

# %% [markdown]
# ### Optional Test Hyperopt

# %%
from hyperopt import hp
from hyperopt import Trials

from scipy import stats

# %%
param_grid = {
    'learning_rate': [0.03, 0.04, 0.05, 0.06],
    'num_leaves': [10, 25, 35],
    'max_depth': [3, 5, 6]
}

param_dist = {
    'learning_rate': stats.uniform(0.02, 0.25),
    'num_leaves': stats.randint(20,40),
    'max_depth': [10, 12]
}

param_dist_hyperopt = {
    'max_depth': 15 + hp.randint('num_leaves', 5), 
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.2)),
    'colsample_bytree': hp.uniform('colsample_by_tree', 0.6, 1.0)
}


regr_xgb = xgb.XGBRegressor(n_estimators=400, random_state=0, verbosity=0, n_jobs=-1)
